# %%
from torch.utils.data import Dataset
from torchvision.transforms import ToTensor
from torchvision import datasets
from torch.utils.data import DataLoader
import torchvision.transforms as transforms
from GAN import GAN
import os

from data import MonetDataset

# %%
ds = MonetDataset(None, os.getcwd()+"/images") #absoulute path

dataloader = DataLoader(dataset=ds, batch_size=32)

# %%
def train(n_epochs, model):
    for _ in range(n_epochs):
        for batch in dataloader:
            model.train(batch)
        model.plot_samples()

# %%
model = GAN(100, (256, 256))
model.plot_samples()
train(10000, model)
# Out:
# disc:  tensor(19.1366, device='cuda:0', grad_fn=<DivBackward0>)
# gen:  tensor(22.2703, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# disc:  tensor(16.0590, device='cuda:0', grad_fn=<DivBackward0>)
# gen:  tensor(18.9787, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# disc:  tensor(11.6251, device='cuda:0', grad_fn=<DivBackward0>)
# gen:  tensor(0.2287, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 model = GAN(100, (256, 256))
#       2 model.plot_samples()
# ----> 3 train(10000, model)
#
# Cell In[3], line 4, in train(n_epochs, model)
#       2 for _ in range(n_epochs):
#       3     for batch in dataloader:
# ----> 4         model.train(batch)
#       5     model.plot_samples()
#
# File ~/GANs/GAN.py:121, in GAN.train(self, batch)
#     119 yp = self.discrimiantor(fake_imgs)
#     120 fake_loss = self.loss(y_pred=yp, y_true=fake_labels)
# --> 121 real_loss = self.loss(y_pred=self.discrimiantor(real_imgs.to(device=self.device)), y_true=real_labels)
#     123 loss = (fake_loss + real_loss)/2
#     124 self.d_optim.zero_grad()
#
# KeyboardInterrupt:
